# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\dell\\demo\\贷与不贷，机器学习决策树loans.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-47bf1664e121> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('C:\\Users\\dell\\demo\\贷与不贷，机器学习决策树loans.csv')
#
# ...

# %%
df.head()

# %%
df.shape

# %%
X = df.drop('safe_loans',axis=1)
y = df.safe_loans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f8a2146b1120> in <module>()
# ----> 1 X = df.drop('safe_loans',axis=1)
#       2 y = df.safe_loans
#
# NameError: name 'df' is not defined

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-270dd209b8a9> in <module>()
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
y.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-57c5b46652b0> in <module>()
# ----> 1 y.shape
#
# NameError: name 'y' is not defined

# %%
X.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-90747f7fe107> in <module>()
#       5
#       6
# ----> 7 X.head()
#
# NameError: name 'X' is not defined

# %%
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict

d = defaultdict(LabelEncoder)
X_trans = X.apply(lambda x: d[x.name].fit_transform(x))
X_trans.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-983f61a77e3d> in <module>()
#       3
#       4 d = defaultdict(LabelEncoder)
# ----> 5 X_trans = X.apply(lambda x: d[x.name].fit_transform(x))
#       6 X_trans.head()
#
# NameError: name 'X' is not defined

# %%
from sklearn.cross_validation import train_test_split

X_trans , X_test , y_tran , y_test = train_test_split(X_trans,y,random_state=1)

# %%
X_trans.shape

# %%
X_test.shape
# Out:
# (11627, 12)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=3)
clf = clf.fit(X_trans,y_tran)

# %%
with open("safe-loans.dot",'w') as f:
    f = tree.export_graphviz(clf,
                            out_file=f,
                            max_depth=3,
                            impurity = True,
                            feature_names = list(X_trans),
                            class_names = ['not safe','safe'],
                            rounded = True,
                            filled = True)
#from nt import chdir
#import os
#chdir(os.path.dirname("C:\\Users\\dell\\demo"))
from subprocess import check_call 
check_call(['C:\\Program Files (x86)\\Graphviz2.38\\bin\\dot','-Tpng','safe-loans.dot','-o','safe-loans.png'])

from IPython.display import Image as PImage
from PIL import Image,ImageDraw,ImageFont
img = Image.open("safe-loans.png")
draw = ImageDraw.Draw(img)
img.save('output.png')
PImage("output.png")

# %%
test_rec = X_test.iloc[1,:]
clf.predict([test_rec])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b8c39997bd2e> in <module>()
# ----> 1 test_rec = X_test.iloc[1,:]
#       2 clf.predict([test_rec])
#
# NameError: name 'X_test' is not defined
